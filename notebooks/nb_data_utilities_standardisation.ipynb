# %% [markdown]
# # Data Standardisation
#
# Combining AED and data Wrangling, at the end the csv produced should be a standardised dataset ready for use.

# %%
# Import libraries
import sys
import os
import pandas as pd
from pathlib import Path


sys.path.append("../")
os.getcwd()
from core.data_manager import csv_to_dataframe

# %%
# Variables
path = Path.cwd().parents[0]

raw_data_utilities = path.joinpath("data_storage", "raw_data.csv")

path_water = path.joinpath("data_storage", "water.csv")

path_power = path.joinpath("data_storage", "power.csv")
path_gas = path.joinpath("data_storage", "gas.csv")

# %%
# from raw data create 3 different csv files for water, gas, power
raw_utilities_df = csv_to_dataframe(raw_data_utilities)

# %%
# convert column date to datetime
raw_utilities_df = raw_utilities_df.reset_index()
raw_utilities_df["date"] = pd.to_datetime(raw_utilities_df["date"], format="%d/%m/%Y")

# %%
# # in raw_utilities_df reset index
# raw_utilities_df = raw_utilities_df.reset_index()

# %%
raw_utilities_df.tail(50)
# Out:
#           date      time  days  g_id_meter     gas_m3   g_cons     g_av_day  \
# 123 2023-05-03       NaN  27.0         1.0  47 167,99    29,19         1,08
# 124 2023-06-01       NaN  29.0         1.0  47 199,23    31,25         1,08
# 125 2023-06-17       NaN  16.0         1.0  47 215,24    16,00         1,00
# 126 2023-06-22       NaN   5.0         1.0  47 220,32     5,08         1,02
# 127 2023-07-05       NaN  13.0         1.0  47 231,96    11,65         0,90
# 128 2023-08-03       NaN  29.0         1.0  47 239,09     7,13         0,25
# 129 2023-08-10       NaN   7.0         1.0  47 241,39     2,30         0,33
# 130 2023-09-01       NaN  22.0         1.0  47 258,17    16,79         0,76
# 131 2023-11-01       NaN  61.0         1.0  47 331,04    72,87         1,19
# 132 2023-12-04       NaN  33.0         1.0  47 493,52   162,48         4,92
# 133 2024-01-01       NaN  28.0         1.0  47 633,19   139,67         4,99
# ...

# %%
# function to split raw data into df (water, gas, power), each with columns: date, days, id_meter, meterd_con, cons, av_day. If gas columns name start by g, if water by w, if power by p. Save to csv
def split_raw_utilities(df: pd.DataFrame):
    # df = df.reset_index()
    water_df = df[["date", "days", "w_id_meter", "water_m3", "w_cons", "w_av_day"]].copy()
    water_df.columns = ["date", "days", "id_meter", "metered_con", "cons", "av_day"]
    water_df.columns = water_df.columns.str.replace("w_", "")
    water_df.to_csv(path_water, index=False)

    gas_df = df[["date", "days", "g_id_meter", "gas_m3", "g_cons", "g_av_day"]].copy()
    gas_df.columns = ["date", "days", "id_meter", "metered_con", "cons", "av_day"]
    gas_df.columns = gas_df.columns.str.replace("g_", "")
    gas_df.to_csv(path_gas, index=False)

    power_df = df[["date", "days", "p_id_meter", "power_kwh", "p_cons", "p_av_day"]].copy()
    power_df.columns = ["date", "days", "id_meter", "metered_con", "cons", "av_day"]
    power_df.columns = power_df.columns.str.replace("p_", "")
    power_df.to_csv(path_power, index=False)

    return water_df, gas_df, power_df

water_df, gas_df, power_df = split_raw_utilities(raw_utilities_df)
water_df.head()
# Out:
#         date   days  id_meter metered_con   cons av_day
# 0 2011-06-01    0.0       6.0        1,00   0,00  0,000
# 1 2011-07-12   41.0       6.0       10,00   9,00  0,220
# 2 2012-02-02  205.0       6.0         NaN    NaN    NaN
# 3 2012-03-26   53.0       6.0         NaN    NaN    NaN
# 4 2012-07-12  108.0       6.0      108,00  98,00  0,268

# %%
water_df = csv_to_dataframe(path_water, index_col=False)
gas_df = csv_to_dataframe(path_gas, index_col=False)
power_df = csv_to_dataframe(path_power, index_col=False)

# %%
gas_df
# Out:
#            date   days  id_meter metered_con    cons       av_day
# 0    2011-06-01    0.0       8.0        1,00    0,00         0,00
# 1    2011-07-12   41.0       8.0         NaN     NaN          NaN
# 2    2012-02-02  205.0       8.0      256,62  255,62         1,04
# 3    2012-03-26   53.0       8.0         NaN     NaN          NaN
# 4    2012-07-12  108.0       8.0         NaN     NaN          NaN
# ..          ...    ...       ...         ...     ...          ...
# 168  2025-10-02   31.0       1.0   49 262,22   32,41         1,05
# 169  2025-10-12   10.0       1.0   49 274,03   11,82         1,18
# 170  2025-10-23   11.0       1.0   49 287,49   13,46  1,223636364
# 171  2025-10-24    1.0       1.0   49 288,98   1,483        1,483
# 172  2025-11-01    8.0       1.0   49 326,15  37,177     4,647125
#
# [173 rows x 6 columns]

# %%
water_df.head()
# Out:
#          date   days  id_meter metered_con   cons av_day
# 0  2011-06-01    0.0       6.0        1,00   0,00  0,000
# 1  2011-07-12   41.0       6.0       10,00   9,00  0,220
# 2  2012-02-02  205.0       6.0         NaN    NaN    NaN
# 3  2012-03-26   53.0       6.0         NaN    NaN    NaN
# 4  2012-07-12  108.0       6.0      108,00  98,00  0,268

# %%
power_df
# Out:
#            date   days  id_meter meterd_con      cons       av_day
# 0    2011-06-01    0.0       7.0          0      0,00         0,00
# 1    2011-07-12   41.0       7.0        NaN       NaN          NaN
# 2    2012-02-02  205.0       7.0        NaN       NaN          NaN
# 3    2012-03-26   53.0       7.0     1216,5  1 216,50         4,07
# 4    2012-07-12  108.0       7.0        NaN       NaN          NaN
# ..          ...    ...       ...        ...       ...          ...
# 168  2025-10-02   31.0       5.0     5446,4     97,00         3,13
# 169  2025-10-12   10.0       5.0     5487,8     41,40         4,14
# 170  2025-10-23   11.0       5.0     5525,5     37,70  3,427272727
# 171  2025-10-24    1.0       5.0     5531,1      5,60          5,6
# 172  2025-11-01    8.0       5.0     5560,5     29,40        3,675
#
# [173 rows x 6 columns]

# %%
# function to add id_meter
# def adding_data_meter_id(df):
#     df_process = df.copy()
#     # if water is part of
#     if "water" in df.columns:
#         df_process["id_meter"] = 1
#     # if df is gas
#     if "gas" in df.columns:
#         df_process["id_meter"] = 2
#     # if df is power
#     if "power" in df.columns:
#         df_process["id_meter"] = 3
#     # # if df is not water, gas or power
#     # if (
#     #     "water" not in df.columns
#     #     and "gas" not in df.columns
#     #     and "power" not in df.columns
#     # ):
#     #     print("The dataframe is not water, gas or power")
#     # if id_meter is 1 and date is lower than 2014-10-02
#     if df_process["id_meter"].iloc[0] == 1 & df_process["date"].iloc[0] < "2014-10-02":
#         df_process["id_meter"] = 4
#         # if id_meter is 1 and date is higher than 2014-10-02 and lower than 2020-10-03 then id_meter is 5
#     # elif (
#     #     df_process["id_meter"].iloc[0]
#     #     == 1 & df_process["date"].iloc[0]
#     #     > "2014-10-02" & df_process["date"].iloc[0]
#     #     < "2020-10-03"
#     # ):
#     #     df_process["id_meter"] = 5
#     # else:
#     #     df_process["id_meter"] = 6

#     # return the df processed
#     return df_process

# %%
# adding_data_meter_id(water_df)

# %% [markdown]
# What is this function doing (below)

# %%
# Function to sort data based in the id_meter, and then in the date
def sort_data(df: pd.DataFrame) -> pd.DataFrame:
    df = df.sort_values(by=["id_meter", "date"])
    # if date empty fill with date_eom
    if "date_eom" in df.columns:
        df["date"] = df["date"].fillna(df["date_eom"])
        df = df.drop(columns=["date_eom"])
    # drop empty rows in column 3
    df = df.dropna(subset=[df.columns[3]])
    # convert date to datetime
    df["date"] = pd.to_datetime(df["date"], dayfirst=True, errors="coerce")
    df = df.sort_values(by=["id_meter", "date"])
    # day_dif column as the difference between the date and the previous date
    df["days"] = df["date"].diff().dt.days
    # # replace 'days' by 'days_dif' and drop 'days_dif' column
    # df['days'] = df['days'].fillna(df['day_dif'])
    # df = df.drop(columns=['day_dif'])
    # if av_day fill with next value
    df["av_day"] = df["av_day"].bfill()
    # sort by date
    df = df.sort_values(by=["date"])

    return df


water_df = sort_data(water_df)
gas_df = sort_data(gas_df)
power_df = sort_data(power_df)

# %%
power_df
# Out:
#           date    days  id_meter meterd_con      cons       av_day
# 0   2011-06-01 -5267.0       7.0          0      0,00         0,00
# 3   2012-03-26   299.0       7.0     1216,5  1 216,50         4,07
# 7   2014-02-04   680.0       7.0     2565,5  1 349,00         1,10
# 10  2014-09-04     NaN       4.0    51419,3      0,00         0,00
# 9   2014-10-02   240.0       7.0     3448,7    883,20         1,10
# ..         ...     ...       ...        ...       ...          ...
# 168 2025-10-02    31.0       5.0     5446,4     97,00         3,13
# 169 2025-10-12    10.0       5.0     5487,8     41,40         4,14
# 170 2025-10-23    11.0       5.0     5525,5     37,70  3,427272727
# 171 2025-10-24     1.0       5.0     5531,1      5,60          5,6
# 172 2025-11-01     8.0       5.0     5560,5     29,40        3,675
#
# [161 rows x 6 columns]

# %%
water_df.head(50)
# Out:
#          date   days  id_meter  water_m3   cons av_day
# 10 2014-09-04    NaN       2.0    114.42   0.00      0
# 12 2014-11-28   85.0       2.0    142.03  27.62    325
# 13 2014-12-16   18.0       2.0    148.27   6.24    347
# 15 2015-07-01  197.0       2.0    209.16  60.89    309
# 16 2015-07-23   22.0       2.0    209.16   0.00      0
# 17 2015-09-08   47.0       2.0    214.21   5.05    107
# 18 2015-10-01   23.0       2.0    225.10  10.89    473
# 20 2015-12-01   61.0       2.0    239.39  14.29    234
# 21 2015-12-16   15.0       2.0    243.83   4.43    295
# 22 2016-01-01   16.0       2.0    246.73   2.91    182
# 23 2016-01-07    6.0       2.0    247.72   0.99    165
# 24 2016-01-17   10.0       2.0    249.37   1.65    165
# 25 2016-01-21    4.0       2.0    250.03   0.66    165
# 26 2016-02-01   11.0       2.0    253.60   3.57    324
# 27 2016-02-16   15.0       2.0    259.30   5.70    380
# 28 2016-03-01   14.0       2.0    264.43   5.14    367
# ...

# %%
# Function resampling independently for each meter, dropping the columns ['av_day', 'days'], normalising numeric columns and interpolating the data


def resample_data(df: pd.DataFrame, freq: str, name: str) -> pd.DataFrame:
    df_temp = df.copy()

    # drop completely empty index-like column if present
    if "Unnamed: 0" in df_temp.columns:
        df_temp = df_temp.drop(columns=["Unnamed: 0"])

    # group the data by meter id and build list of dataframes
    grouped = df_temp.groupby("id_meter")
    df_list = [grouped.get_group(x).copy() for x in grouped.groups]

    for i in range(len(df_list)):
        dfi = df_list[i]

        # Normalize object columns that may contain commas as decimal separators
        obj_cols = dfi.select_dtypes(include=["object"]).columns.tolist()
        for col in obj_cols:
            dfi[col] = dfi[col].astype(str).str.replace(",", ".", regex=False)

        # Convert all non-date, non-id_meter columns to numeric (coerce errors to NaN)
        for col in dfi.columns:
            if col not in ["date", "id_meter"]:
                dfi[col] = pd.to_numeric(dfi[col], errors="coerce")

        # drop unnecessary columns if present
        columns_drop = ["days", "av_day", "cons"]
        columns_drop = [col for col in columns_drop if col in dfi.columns]
        if columns_drop:
            dfi = dfi.drop(columns=columns_drop)

        # ensure date is datetime and set as index for resampling
        dfi["date"] = pd.to_datetime(dfi["date"], errors="coerce")
        dfi = dfi.set_index("date")

        # resample taking the mean (all columns should be numeric now)
        try:
            dfi = dfi.resample(freq).mean()
        except TypeError:
            # fallback: coerce everything to numeric then resample
            dfi = dfi.apply(pd.to_numeric, errors="coerce")
            dfi = dfi.resample(freq).mean()

        # interpolate by time
        dfi = dfi.interpolate(method="time")

        # reset index and restore id_meter column (was lost during resample)
        dfi = dfi.reset_index()
        meter_id = df_list[i]["id_meter"].iloc[0]
        dfi["id_meter"] = meter_id

        # determine consumption column for calc_cons
        possible_cons = [c for c in dfi.columns if c in ["cons", "water_m3", "gas_m3", "power_kwh"]]
        if possible_cons:
            cons_col = possible_cons[0]
        else:
            # fallback: use third column if available
            if dfi.shape[1] >= 3:
                cons_col = dfi.columns[2]
            else:
                cons_col = None

        # compute calc_cons safely
        if cons_col is not None:
            dfi = dfi.sort_values("date")
            dfi["calc_cons"] = dfi[cons_col].diff()
        else:
            dfi["calc_cons"] = pd.NA

        print("Dataframe shape: ", dfi.shape)
        df_list[i] = dfi

    # merge the dataframes
    df_temp = pd.concat(df_list, ignore_index=True)

    # sort the data by id_meter and date
    df_temp = df_temp.sort_values(by=["id_meter", "date"])

    # save the df in a csv file with the name 'resampled_data_'+freq+'_'+name at the data_storage folder
    df_temp.to_csv("../data_storage/resampled_data_" + freq + "_" + name + ".csv", index=False)
    return df_temp


interpolated_water_df = resample_data(water_df, "D", "water")
interpolated_gas_df = resample_data(gas_df, "D", "gas")
interpolated_power_df = resample_data(power_df, "D", "power")
# Out:
# Dataframe shape:  (1994, 4)
# Dataframe shape:  (2064, 4)
# Dataframe shape:  (1220, 4)
# Dataframe shape:  (3740, 4)
# Dataframe shape:  (1183, 4)
# Dataframe shape:  (2552, 4)
# Dataframe shape:  (1278, 4)
# Dataframe shape:  (1183, 4)

# %%
print(interpolated_water_df)
# Out:
#            date  id_meter    water_m3  calc_cons
# 0    2014-09-04       2.0  114.420000        NaN
# 1    2014-09-05       2.0  114.744824   0.324824
# 2    2014-09-06       2.0  115.069647   0.324824
# 3    2014-09-07       2.0  115.394471   0.324824
# 4    2014-09-08       2.0  115.719294   0.324824
# ...         ...       ...         ...        ...
# 5273 2014-09-28       6.0  334.125000   0.218750
# 5274 2014-09-29       6.0  334.343750   0.218750
# 5275 2014-09-30       6.0  334.562500   0.218750
# 5276 2014-10-01       6.0  334.781250   0.218750
# 5277 2014-10-02       6.0  335.000000   0.218750
#
# [5278 rows x 4 columns]

# %%
interpolated_water_df.tail()
# Out:
#            date  id_meter   water_m3  calc_cons
# 5273 2014-09-28       6.0  334.12500    0.21875
# 5274 2014-09-29       6.0  334.34375    0.21875
# 5275 2014-09-30       6.0  334.56250    0.21875
# 5276 2014-10-01       6.0  334.78125    0.21875
# 5277 2014-10-02       6.0  335.00000    0.21875

# %%
# function to sort and save as csv the intepolated df
def save_daily_data(df: pd.DataFrame, name: str):
    daily_df = df.sort_values(by=["id_meter", "date"])
    daily_df.to_csv("../data_storage/daily_" + name + "_data.csv", index=False)
    return daily_df

daily_water_df = save_daily_data(interpolated_water_df, "water")
daily_gas_df = save_daily_data(interpolated_gas_df, "gas")
daily_power_df = save_daily_data(interpolated_power_df, "power")

# %%
# function to group by month and year, aggregating by sum
def group_data_month(df: pd.DataFrame, name: str) -> pd.DataFrame:
    df_temp = df.copy()
    # add columns with year and month
    df_temp["year"] = df_temp["date"].dt.year
    df_temp["month"] = df_temp["date"].dt.month
    # drop date column
    df_temp = df_temp.drop(columns=["date"])
    # group by id_meter, year and month, aggregating by sum
    df_temp = df_temp.groupby(
        [
            "year",
            "month",
            "id_meter",
        ]
    ).sum()
    # merge the columns year and month and assign the last day of the month
    df_temp = df_temp.reset_index()
    df_temp["date"] = pd.to_datetime(df_temp[["year", "month"]].assign(day=1))
    df_temp["date"] = df_temp["date"] + pd.offsets.MonthEnd(0)
    # drop year and month columns
    df_temp = df_temp.drop(columns=["year", "month"])
    # set the date as index
    df_temp = df_temp.set_index("date")
    # reset index
    df_temp = df_temp.reset_index()
    # sort the data by id_meter and date
    df_temp = df_temp.sort_values(by=["id_meter", "date"])
    # save the df in a csv file with the name 'grouped_data_month_'+name at the data_storage folder
    df_temp.to_csv("../data_storage/grouped_data_month_" + name + ".csv", index=False)
    return df_temp


grouped_water_df = group_data_month(interpolated_water_df, "water")
grouped_gas_df = group_data_month(interpolated_gas_df, "gas")
grouped_power_df = group_data_month(interpolated_power_df, "power")

# %%
# function to group data by year, aggregating by sum
def group_data_year(df: pd.DataFrame, name: str) -> pd.DataFrame:
    df_temp = df.copy()
    # add column with year
    df_temp["year"] = df_temp["date"].dt.year
    # drop date column
    df_temp = df_temp.drop(columns=["date"])
    # group by id_meter and year, aggregating by sum
    df_temp = df_temp.groupby(
        [
            "year",
            "id_meter",
        ]
    ).sum()
    # reset index
    df_temp = df_temp.reset_index()
    # create date column with the last day of the year
    df_temp["date"] = pd.to_datetime(df_temp["year"].astype(str) + "-12-31")
    # drop year column
    df_temp = df_temp.drop(columns=["year"])
    # set the date as index
    df_temp = df_temp.set_index("date")
    # reset index
    df_temp = df_temp.reset_index()
    # sort the data by id_meter and date
    df_temp = df_temp.sort_values(by=["id_meter", "date"])
    # save the df in a csv file with the name 'grouped_data_year_'+name at the data_storage folder
    df_temp.to_csv("../data_storage/grouped_data_year_" + name + ".csv", index=False)
    return df_temp
grouped_water_year_df = group_data_year(interpolated_water_df, "water")
grouped_gas_year_df = group_data_year(interpolated_gas_df, "gas")
grouped_power_year_df = group_data_year(interpolated_power_df, "power")
# grouped_power_year_df.tail()
# grouped_power_year_df
# interpolated_water_df = resample_data(water_df, "D", "water")
# interpolated_water_df.head()
# interpolated_water_df.tail()
