# %% [markdown]
# # Import images and convert the image to txt file to exctract measures

# %% [markdown]
# # Objective
# Develope a function(s) that convert images (from camera, server, ...) in text, and then insert that text in the DB in the right place using the data_manager.py and the function appropiate
