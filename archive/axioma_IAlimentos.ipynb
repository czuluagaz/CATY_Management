# %% [markdown]
# # Axioma DB

# %%
# import libraries
import sys
import os

import pathlib
import numpy as np
import pandas as pd
from re import U

from ydata_profiling import ProfileReport

sys.path.append("../")

# %%
# append the path to the current directory

ia_path = "/home/dev/projects/CATY_Management/data_storage/user_portal_datum_2024-07-15_16h13m26.csv"


# import file paths portales IA 
df_portal_ia = pd.read_csv(ia_path)

# %%
df_portal_ia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24049 entries, 0 to 24048
# Data columns (total 60 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Id                                  24049 non-null  int64
#  1   Grupo cargo                         24049 non-null  object
#  2   Cargo                               24049 non-null  object
#  3   Grupo actividad                     24049 non-null  object
#  4   Actividad de la empresa             24049 non-null  object
#  5   Numero empleados                    24049 non-null  object
#  6   Productos empresa                   24049 non-null  object
#  7   Participacion compra                24049 non-null  object
#  8   Participacion evento                24049 non-null  object
#  9   Impreso                             24049 non-null  object
#  10  Digital                             24049 non-null  object
# ...

# %%
# create a profile report
profile_ia = ProfileReport(df_portal_ia, title="AXIOMA - IA Portal", explorative=True)

# save the report
profile_ia.to_file("ia_portal_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /home/dev/projects/CATY_Management/.venv/lib/python3.10/site-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: 'Elaboración de almidones y productos derivados del almidón'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_portal_ia.head()
# Out:
#        Id                             Grupo cargo                   Cargo  \
# 0  111108                                      -                       -
# 1  111116                                      -                       -
# 2  111687                                      -                       -
# 3  111719  Otros títulos / Gobierno / Bibliotecas  Profesor universitario
# 4  111740  Otros títulos / Gobierno / Bibliotecas                      -
#
#           Grupo actividad                            Actividad de la empresa  \
# 0              Farináceos  Elaboración de almidones y productos derivados...
# 1     Bebidas alcohólicas                                Bebidas alcohólicas
# 2  Gremios y asociaciones                             Gremios y asociaciones
# 3                      -                                                  -
# 4     Lácteos y derivados  Procesamiento y conservación de productos láct...
#
#   Numero empleados Productos empresa Participacion compra  \
# ...

# %%
df_portal_ia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24049 entries, 0 to 24048
# Data columns (total 60 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Id                                  24049 non-null  int64
#  1   Grupo cargo                         24049 non-null  object
#  2   Cargo                               24049 non-null  object
#  3   Grupo actividad                     24049 non-null  object
#  4   Actividad de la empresa             24049 non-null  object
#  5   Numero empleados                    24049 non-null  object
#  6   Productos empresa                   24049 non-null  object
#  7   Participacion compra                24049 non-null  object
#  8   Participacion evento                24049 non-null  object
#  9   Impreso                             24049 non-null  object
#  10  Digital                             24049 non-null  object
# ...

# %%
# Function to convert to datetime columns. list of columns to convert: Updated at [User], Creado [User], Created at [Portal], Updated at [Portal], Updated at, Creado
# def convert_to_datetime(df, columns):
#     for col in columns:
#         df[col] = pd.to_datetime(df[col], errors='coerce')
#     return df

# list_columns = ['Updated at [User]', 'Creado [User]', 'Created at [Portal]', 'Updated at [Portal]', 'Updated at', 'Creado']

# df_portal_ia = convert_to_datetime(df_portal_ia, list_columns)

df_portal_ia.head()
# Out:
#        Id                             Grupo cargo                   Cargo  \
# 0  111108                                      -                       -
# 1  111116                                      -                       -
# 2  111687                                      -                       -
# 3  111719  Otros títulos / Gobierno / Bibliotecas  Profesor universitario
# 4  111740  Otros títulos / Gobierno / Bibliotecas                      -
#
#           Grupo actividad                            Actividad de la empresa  \
# 0              Farináceos  Elaboración de almidones y productos derivados...
# 1     Bebidas alcohólicas                                Bebidas alcohólicas
# 2  Gremios y asociaciones                             Gremios y asociaciones
# 3                      -                                                  -
# 4     Lácteos y derivados  Procesamiento y conservación de productos láct...
#
#   Numero empleados Productos empresa Participacion compra  \
# ...

# %%
# unique values in the columns



def unique_values(df):
    for col in df.columns:
        print(f"{col}: {df[col].unique()}")
        print("\n")
    return df

unique_values(df_portal_ia)
# Out:
# Id: [111108 111116 111687 ... 340201 340203 340204]
#
#
# Grupo cargo: [' - ' 'Otros títulos / Gobierno / Bibliotecas' 'Gerencia Corporativa'
#  'Personal Operativo' 'Gerencia Administrativa / Comercial / De Compras'
#  'Gerencia de Operaciones'
#  'Gerencia Administrativa / Comercial / De Compra']
#
#
# Cargo: [' - ' 'Profesor universitario' 'Director / Gerente / CEO General'
#  'Coordinador / Analista  / Asistente  de Compras'
#  'Director / Gerente / Jefe de marca'
#  'Ingeniero de Investigación y Desarrollo' 'Propietario / Dueño / Socio'
#  'Educador / Capacitador / Instructor'
#  'Coordinador / Analista  / Asistente de Mercadeo' 'Asesor / Consultor'
#  'Coordinador / Analista / Asistente de Calidad o inocuidad'
#  'Coordinador / Analista / Asistente de Investigación y Desarrollo'
#  'Jefe de Calidad o inocuidad' 'Director / Gerente / Jefe Administrativo'
#  'Ingeniero de aplicaciones / Asesor técnico'
#  'Director / Jefe de Biblioteca' 'Asesor comercial/ ventas'
# ...

# %%
# name of the columns
df_portal_ia.columns
# Out:
# Index(['id', 'grupo_cargo', 'cargo', 'grupo_actividad',
#        'actividad_de_la_empresa', 'numero_empleados', 'productos_empresa',
#        'participacion_compra', 'participacion_evento', 'impreso', 'digital',
#        'evento', 'boletin', 'responsabilidad_decision_de_compra',
#        'ingresos_operacionales', 'utm_source', 'utm_medium', 'utm_campaign',
#        'referrer_name', 'nit', 'numero_de_identificacion',
#        'tipo_de_identificacion', 'nombre_portal', 'creado', 'updated_at',
#        'evento_participacion', 'evento_participaciones', 'webinar',
#        'webinar_participacion', 'webinar_participaciones', 'desuscrito',
#        'canal_desuscripción', 'modificado_por', 'id_[user]', 'email_[user]',
#        'email_laboral_[user]', 'nombre_[user]', 'apellidos_[user]',
#        'indicativo_pais_[user]', 'telefono_[user]', 'celular_[user]',
#        'pais_[user]', 'ciudad_[user]', 'empresa_[user]', 'direccion_[user]',
# ...

# %%
# in column "pais" replace the values "México" by "Mexico", "Colombia", "CO", "COLOMBIA" by "Colombia"
df_portal_ia["Pais [User]"] = df_portal_ia["Pais [User]"].replace(["México", "Colombia", "CO", "COLOMBIA"], ["Mexico", "Colombia", "Colombia", "Colombia"])

# %%
# functio to count values per unique values in a column
def count_values(df, column):
    return df[column].value_counts()

count_values(df_portal_ia, "Pais [User]")
# Out:
# Pais [User]
# Colombia                   23988
# Costa Rica                    57
# COLOMBIA                       2
# CO                             1
# Cocos (Keeling) Islands        1
# Name: count, dtype: int64

# %%
# describe df
df_portal_ia.describe()

# check for missing values
df_portal_ia.isnull().sum()

# unique values quantity
df_portal_ia.nunique()
# Out:
# Id                                    24049
# Grupo cargo                               7
# Cargo                                   118
# Grupo actividad                          14
# Actividad de la empresa                  32
# Numero empleados                          1
# Productos empresa                         1
# Participacion compra                      1
# Participacion evento                      1
# Impreso                                   2
# Digital                                   2
# Evento                                    2
# Boletin                                   2
# Responsabilidad decision de compra        1
# Ingresos operacionales                    1
# Utm source                                1
# Utm medium                                1
# Utm campaign                              1
# Referrer name                             1
# Nit                                       1
# Numero de identificacion                  1
# ...
